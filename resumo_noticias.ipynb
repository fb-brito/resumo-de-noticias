# %%
import requests
from bs4 import BeautifulSoup
from googletrans import Translator
import win32com.client as win32  # Biblioteca para manipular o Outlook
from PIL import Image
import base64
import os

def get_news_globo():
    url = 'https://www.globo.com/'
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    noticias = soup.find_all('a')

    tgt_class1 = 'post__title'
    tgt_class2 = 'post-multicontent__link__text'

    news_dict = {}
    index = 1  # Inicializa o índice

    for noticia in noticias:
        if (noticia.h2 is not None) and (noticia.h2.get('class') is not None):
            if tgt_class1 in noticia.h2.get('class'):
                news_dict[f"{index}. {noticia.h2.text.strip()}"] = noticia.get('href')
                index += 1
            elif tgt_class2 in noticia.h2.get('class'):
                news_dict[f"{index}. {noticia.h2.text.strip()}"] = noticia.get('href')
                index += 1

    return news_dict

def get_news_scmp():
    base_url = 'https://www.scmp.com'  # Base do URL do site
    url = f'{base_url}/home'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'  # Adiciona um User-Agent para evitar bloqueios
    }
    page = requests.get(url, headers=headers)
    
    if page.status_code != 200:
        print(f"Falha ao acessar a página. Status code: {page.status_code}")
        return {}
    
    soup = BeautifulSoup(page.text, 'html.parser')

    noticias = soup.find_all('a')

    news_dict = {}
    index = 1  # Inicializa o índice
    translator = Translator()  # Inicializa o tradutor

    for noticia in noticias:
        titulo_original = noticia.get_text(strip=True)
        href = noticia.get('href')
        
        if titulo_original and href and len(titulo_original) > 20:
            # Verifica se o link é relativo e adiciona o base_url se necessário
            if href.startswith('/'):
                href = base_url + href
            
            try:
                titulo_traduzido = translator.translate(titulo_original, src='auto', dest='pt').text
            except Exception as e:
                titulo_traduzido = titulo_original
                print(f"Erro ao traduzir título: '{titulo_original}'. Erro: {e}")
            
            news_dict[f"{index}. {titulo_traduzido}"] = href
            index += 1

    return news_dict

def get_news_rt():
    base_url = 'https://www.rt.com'  # Base do URL do site
    url = f'{base_url}/news/'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'  # Adiciona um User-Agent para evitar bloqueios
    }
    page = requests.get(url, headers=headers)
    
    if page.status_code != 200:
        print(f"Falha ao acessar a página. Status code: {page.status_code}")
        return {}
    
    soup = BeautifulSoup(page.text, 'html.parser')

    noticias = soup.find_all('a')

    news_dict = {}
    index = 1  # Inicializa o índice
    translator = Translator()  # Inicializa o tradutor

    for noticia in noticias:
        titulo_original = noticia.get_text(strip=True)
        href = noticia.get('href')
        
        if titulo_original and href and len(titulo_original) > 20:
            # Verifica se o link é relativo e adiciona o base_url se necessário
            if href.startswith('/'):
                href = base_url + href
            
            try:
                titulo_traduzido = translator.translate(titulo_original, src='auto', dest='pt').text
            except Exception as e:
                titulo_traduzido = titulo_original
                print(f"Erro ao traduzir título: '{titulo_original}'. Erro: {e}")
            
            news_dict[f"{index}. {titulo_traduzido}"] = href
            index += 1

    return news_dict

def get_news_nknews():
    base_url = 'https://www.nknews.org'  # Base do URL do site
    url = f'{base_url}/'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'  # Adiciona um User-Agent para evitar bloqueios
    }
    page = requests.get(url, headers=headers)
    
    if page.status_code != 200:
        print(f"Falha ao acessar a página. Status code: {page.status_code}")
        return {}
    
    soup = BeautifulSoup(page.text, 'html.parser')

    noticias = soup.find_all('a')

    news_dict = {}
    index = 1  # Inicializa o índice
    translator = Translator()  # Inicializa o tradutor

    for noticia in noticias:
        titulo_original = noticia.get_text(strip=True)
        href = noticia.get('href')
        
        if titulo_original and href and len(titulo_original) > 20:
            # Verifica se o link é relativo e adiciona o base_url se necessário
            if href.startswith('/'):
                href = base_url + href
            
            try:
                titulo_traduzido = translator.translate(titulo_original, src='auto', dest='pt').text
            except Exception as e:
                titulo_traduzido = titulo_original
                print(f"Erro ao traduzir título: '{titulo_original}'. Erro: {e}")
            
            news_dict[f"{index}. {titulo_traduzido}"] = href
            index += 1

    return news_dict

def get_news_shine():
    base_url = 'https://www.shine.cn'  # Base do URL do site
    url = f'{base_url}/news/'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'  # Adiciona um User-Agent para evitar bloqueios
    }
    page = requests.get(url, headers=headers)
    
    if page.status_code != 200:
        print(f"Falha ao acessar a página. Status code: {page.status_code}")
        return {}
    
    soup = BeautifulSoup(page.text, 'html.parser')

    noticias = soup.find_all('a')

    news_dict = {}
    index = 1  # Inicializa o índice
    translator = Translator()  # Inicializa o tradutor

    for noticia in noticias:
        titulo_original = noticia.get_text(strip=True)
        href = noticia.get('href')
        
        if titulo_original and href and len(titulo_original) > 20:
            # Verifica se o link é relativo e adiciona o base_url se necessário
            if href.startswith('/'):
                href = base_url + href
            
            try:
                titulo_traduzido = translator.translate(titulo_original, src='auto', dest='pt').text
            except Exception as e:
                titulo_traduzido = titulo_original
                print(f"Erro ao traduzir título: '{titulo_original}'. Erro: {e}")
            
            news_dict[f"{index}. {titulo_traduzido}"] = href
            index += 1

    return news_dict

def get_news_sputnik():
    base_url = 'https://sputnikglobe.com'  # Base do URL do site
    url = f'{base_url}/'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'  # Adiciona um User-Agent para evitar bloqueios
    }
    page = requests.get(url, headers=headers)
    
    if page.status_code != 200:
        print(f"Falha ao acessar a página. Status code: {page.status_code}")
        return {}
    
    soup = BeautifulSoup(page.text, 'html.parser')

    noticias = soup.find_all('a')

    news_dict = {}
    index = 1  # Inicializa o índice
    translator = Translator()  # Inicializa o tradutor

    for noticia in noticias:
        titulo_original = noticia.get_text(strip=True)
        href = noticia.get('href')
        
        if titulo_original and href and len(titulo_original) > 20:
            # Verifica se o link é relativo e adiciona o base_url se necessário
            if href.startswith('/'):
                href = base_url + href
            
            try:
                titulo_traduzido = translator.translate(titulo_original, src='auto', dest='pt').text
            except Exception as e:
                titulo_traduzido = titulo_original
                print(f"Erro ao traduzir título: '{titulo_original}'. Erro: {e}")
            
            news_dict[f"{index}. {titulo_traduzido}"] = href
            index += 1

    return news_dict

# Funções para os novos sites

def get_news_iclnoticias():
    base_url = 'https://iclnoticias.com.br/'
    page = requests.get(base_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    noticias = soup.find_all('a')

    news_dict = {}
    index = 1  # Inicializa o índice

    for noticia in noticias:
        titulo_original = noticia.get_text(strip=True)
        href = noticia.get('href')

        if titulo_original and href and len(titulo_original) > 20:
            if href.startswith('/'):
                href = base_url + href

            news_dict[f"{index}. {titulo_original}"] = href
            index += 1

    return news_dict

def get_news_brasil247():
    base_url = 'https://www.brasil247.com/'
    page = requests.get(base_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    noticias = soup.find_all('a')

    news_dict = {}
    index = 1  # Inicializa o índice

    for noticia in noticias:
        titulo_original = noticia.get_text(strip=True)
        href = noticia.get('href')

        if titulo_original and href and len(titulo_original) > 20:
            if href.startswith('/'):
                href = base_url + href

            news_dict[f"{index}. {titulo_original}"] = href
            index += 1

    return news_dict

def get_news_jornalggn():
    base_url = 'https://jornalggn.com.br/'
    page = requests.get(base_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    noticias = soup.find_all('a')

    news_dict = {}
    index = 1  # Inicializa o índice

    for noticia in noticias:
        titulo_original = noticia.get_text(strip=True)
        href = noticia.get('href')

        if titulo_original and href and len(titulo_original) > 20:
            if href.startswith('/'):
                href = base_url + href

            news_dict[f"{index}. {titulo_original}"] = href
            index += 1

    return news_dict

def get_news_news_cn():
    base_url = 'https://portuguese.news.cn/index.htm'
    page = requests.get(base_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    noticias = soup.find_all('a')

    news_dict = {}
    index = 1  # Inicializa o índice
    
    for noticia in noticias:
        titulo_original = noticia.get_text(strip=True)
        href = noticia.get('href')

        if titulo_original and href and len(titulo_original) > 20:
            if href.startswith('/'):
                href = base_url + href

            news_dict[f"{index}. {titulo_original}"] = href
            index += 1

    return news_dict

def get_news_noticiabrasil():
    base_url = 'https://noticiabrasil.net.br/'
    page = requests.get(base_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    noticias = soup.find_all('a')

    news_dict = {}
    index = 1  # Inicializa o índice
    
    for noticia in noticias:
        titulo_original = noticia.get_text(strip=True)
        href = noticia.get('href')

        if titulo_original and href and len(titulo_original) > 20:
            if href.startswith('/'):
                href = base_url + href

            news_dict[f"{index}. {titulo_original}"] = href
            index += 1

    return news_dict

def get_news_operamundi():
    base_url = 'https://operamundi.uol.com.br/'
    page = requests.get(base_url)
    soup = BeautifulSoup(page.text, 'html.parser')

    noticias = soup.find_all('a')

    news_dict = {}
    index = 1  # Inicializa o índice

    for noticia in noticias:
        titulo_original = noticia.get_text(strip=True)
        href = noticia.get('href')

        if titulo_original and href and len(titulo_original) > 20:
            if href.startswith('/'):
                href = base_url + href

            news_dict[f"{index}. {titulo_original}"] = href
            index += 1

    return news_dict

def get_news_cnnbrasil():
    url = 'https://www.cnnbrasil.com.br/'
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html.parser')

    noticias = soup.find_all('a')

    tgt_class1 = 'block__news__title'
    tgt_class2 = 'block__news__list'
	
    news_dict = {}
    index = 1  # Inicializa o índice

    for noticia in noticias:
        if (noticia.h3 is not None) and (noticia.h3.get('class') is not None):
            if tgt_class1 in noticia.h3.get('class'):
                news_dict[f"{index}. {noticia.h3.text.strip()}"] = noticia.get('href')
                index += 1
            elif tgt_class2 in noticia.h3.get('class'):
                news_dict[f"{index}. {noticia.h3.text.strip()}"] = noticia.get('href')
                index += 1

    return news_dict

def get_news_thenewyorktimes():
    base_url = 'https://www.nytimes.com/international'  # Base do URL do site
    url = f'{base_url}/'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'  # Adiciona um User-Agent para evitar bloqueios
    }
    page = requests.get(url, headers=headers)
    
    if page.status_code != 200:
        print(f"Falha ao acessar a página. Status code: {page.status_code}")
        return {}
    
    soup = BeautifulSoup(page.text, 'html.parser')

    noticias = soup.find_all('a')

    news_dict = {}
    index = 1  # Inicializa o índice
    translator = Translator()  # Inicializa o tradutor

    for noticia in noticias:
        titulo_original = noticia.get_text(strip=True)
        href = noticia.get('href')
        
        if titulo_original and href and len(titulo_original) > 20:
            # Verifica se o link é relativo e adiciona o base_url se necessário
            if href.startswith('/'):
                href = base_url + href
            
            try:
                titulo_traduzido = translator.translate(titulo_original, src='auto', dest='pt').text
            except Exception as e:
                titulo_traduzido = titulo_original
                print(f"Erro ao traduzir título: '{titulo_original}'. Erro: {e}")
            
            news_dict[f"{index}. {titulo_traduzido}"] = href
            index += 1

    return news_dict

def get_news_thewashingtonpost():
    base_url = 'https://www.washingtonpost.com'  # Base do URL do site
    url = f'{base_url}/'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'  # Adiciona um User-Agent para evitar bloqueios
    }
    page = requests.get(url, headers=headers)
    
    if page.status_code != 200:
        print(f"Falha ao acessar a página. Status code: {page.status_code}")
        return {}
    
    soup = BeautifulSoup(page.text, 'html.parser')

    noticias = soup.find_all('a')

    news_dict = {}
    index = 1  # Inicializa o índice
    translator = Translator()  # Inicializa o tradutor

    for noticia in noticias:
        titulo_original = noticia.get_text(strip=True)
        href = noticia.get('href')
        
        if titulo_original and href and len(titulo_original) > 20:
            # Verifica se o link é relativo e adiciona o base_url se necessário
            if href.startswith('/'):
                href = base_url + href
            
            try:
                titulo_traduzido = translator.translate(titulo_original, src='auto', dest='pt').text
            except Exception as e:
                titulo_traduzido = titulo_original
                print(f"Erro ao traduzir título: '{titulo_original}'. Erro: {e}")
            
            news_dict[f"{index}. {titulo_traduzido}"] = href
            index += 1

    return news_dict

def get_news_theguardian():
    base_url = 'https://www.theguardian.com/international'  # Base do URL do site
    url = f'{base_url}/'
    headers = {
        'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64)'  # Adiciona um User-Agent para evitar bloqueios
    }
    page = requests.get(url, headers=headers)
    
    if page.status_code != 200:
        print(f"Falha ao acessar a página. Status code: {page.status_code}")
        return {}
    
    soup = BeautifulSoup(page.text, 'html.parser')

    noticias = soup.find_all('a')

    news_dict = {}
    index = 1  # Inicializa o índice
    translator = Translator()  # Inicializa o tradutor

    for noticia in noticias:
        titulo_original = noticia.get_text(strip=True)
        href = noticia.get('href')
        
        if titulo_original and href and len(titulo_original) > 20:
            # Verifica se o link é relativo e adiciona o base_url se necessário
            if href.startswith('/'):
                href = base_url + href
            
            try:
                titulo_traduzido = translator.translate(titulo_original, src='auto', dest='pt').text
            except Exception as e:
                titulo_traduzido = titulo_original
                print(f"Erro ao traduzir título: '{titulo_original}'. Erro: {e}")
            
            news_dict[f"{index}. {titulo_traduzido}"] = href
            index += 1

    return news_dict

def image_to_base64(image_path):
    with open(image_path, "rb") as img_file:
        return base64.b64encode(img_file.read()).decode('utf-8')

def get_flag_path(site_name):
    # flag_mapping = {
    #     "SCMP - South China Morning Post - Jornal de língua inglesa de Hong Kong": "hong-kong.png",
    #     "RT - Rede de televisão internacional fundada na Rússia": "Russian Television.png",
    #     "NK News - Site dos Estados Unidos sobre a Coreia do Norte": "coreia-do-norte.png",
    #     "Shine - Shanghai Daily mídia estatal sob o controle do Comitê Municipal de Xangai do Partido Comunista Chinês.": "china.png",
    #     "Sputnik Internacional - Sputnik é uma agência internacional de notícias do governo russo": "russia.png",
    #     "ICL Notícias - Instituto Conhecimento Liberta": "brasil.png",
    #     "Brasil 247 - Portal brasileiro de notícias e análises políticas, com linha editorial identificada com a esquerda política": "brasil.png",
    #     "Jornal GGN - Jornal Grupo Gente Nova": "brasil.png",
    #     "Xinhua - Xinhua Agência de notícias República Popular da China": "china.png",
    #     "Sputnik Brasil": "brasil.png",
    #     "Opera Mundi - Portal de notícias brasileiro": "brasil.png",
    #     "Globo - Canal de televisão comercial aberto brasileiro com editorial alinhado aos EUA.": "brasil.png",
    #     "CNN Brasil - Canal de televisão comercial aberto brasileiro com editorial alinhado aos EUA.": "brasil.png",
    #     "The New York Times - Jornal Diário Estadunidense": "eua.png",
    #     "The Washington Post - Jornal diário americano publicado em Washington, D.C": "eua.png",
    #     "The Guardian - Jornal diário nacional britânico": "reino-unido.png"
    # }
    flag_mapping = {
        "SCMP": "hong-kong.png",
        "RT": "russia.png",
        "NK News": "coreia-do-norte.png",
        "Shine": "china.png",
        "Sputnik Global": "russia.png",
        "ICL Notícias": "brasil.png",
        "Brasil 247": "brasil.png",
        "Jornal GGN": "brasil.png",
        "Xinhua": "china.png",
        "Sputnik Brasil": "brasil.png",
        "Opera Mundi": "brasil.png",
        "Globo": "brasil.png",
        "CNN Brasil": "brasil.png",
        "The New York Times": "eua.png",
        "The Washington Post": "eua.png",
        "The Guardian": "reino-unido.png"
    }

    return os.path.join(r"C:\Users\Flavio de Brito\OneDrive - 3hzrmc\Documentos", "GitHub", "resumo-de-noticias", "bandeiras", flag_mapping.get(site_name.strip(), ""))

def enviar_email(news_dict):
    outlook = win32.Dispatch('outlook.application')
    mail = outlook.CreateItem(0)
    mail.Subject = 'Resumo das Notícias'
    mail.To = 'seu.email@provedor.com'  # Substitua pelo email de destino

    body = '<html><body>'
    body += '<h2>Resumo das principais notícias:</h2>'

    for site, news in news_dict.items():
        flag_image_path = get_flag_path(site)
        
        if flag_image_path:
            flag_base64 = image_to_base64(flag_image_path)
            flag_img_tag = f'<img src="data:image/png;base64,{flag_base64}" width="30" height="30"/>'
        else:
            flag_img_tag = ''  # Se não houver imagem, não inclui nada

        body += f'<h3>{flag_img_tag} {site}</h3><ul>'
        for title, link in news.items():
            body += f'<li><a href="{link}">{title}</a></li>'
        body += '</ul>'
    
    body += '</body></html>'

    mail.HTMLBody = body  # Define o corpo do e-mail como HTML
    mail.Send()

# Obter notícias de todos os sites
noticias_globo = get_news_globo()
noticias_scmp = get_news_scmp()
noticias_rt = get_news_rt()
noticias_nknews = get_news_nknews()
noticias_shine = get_news_shine()
noticias_sputnik = get_news_sputnik()
noticias_iclnoticias = get_news_iclnoticias()
noticias_brasil247 = get_news_brasil247()
noticias_jornalggn = get_news_jornalggn()
noticias_news_cn = get_news_news_cn()
noticias_noticiabrasil = get_news_noticiabrasil()
noticias_operamundi = get_news_operamundi()
noticias_cnnbrasil = get_news_cnnbrasil()
noticias_thenewyorktimes = get_news_thenewyorktimes()
noticias_thewashingtonpost = get_news_thewashingtonpost()
noticias_theguardian = get_news_theguardian()

# Combine todas as notícias em um dicionário organizado por site
# todas_noticias = {
#     "SCMP - South China Morning Post - Jornal de língua inglesa de Hong Kong": noticias_scmp,
#     "RT - Rede de televisão internacional fundada na Rússia": noticias_rt,
#     "NK News - Site dos Estados Unidos sobre a Coreia do Norte": noticias_nknews,
#     "Shine - Shanghai Daily mídia estatal sob o controle do Comitê Municipal de Xangai do Partido Comunista Chinês.": noticias_shine,
#     "Sputnik Internacional - Sputnik é uma agência internacional de notícias do governo russo": noticias_sputnik,
#     "ICL Notícias - Instituto Conhecimento Liberta": noticias_iclnoticias,
#     "Brasil 247 - Portal brasileiro de notícias e análises políticas, com linha editorial identificada com a esquerda política": noticias_brasil247,
#     "Jornal GGN - Jornal Grupo Gente Nova": noticias_jornalggn,
#     "Xinhua - Xinhua Agência de notícias República Popular da China": noticias_news_cn,
#     "Sputnik Brasil": noticias_noticiabrasil,
#     "Opera Mundi - Portal de notícias brasileiro": noticias_operamundi,
#     "Globo - Canal de televisão comercial aberto brasileiro com editorial alinhado aos EUA.": noticias_globo,
#     "CNN Brasil - Canal de televisão comercial aberto brasileiro com editorial alinhado aos EUA.": noticias_cnnbrasil,
#     "The New York Times - Jornal Diário Estadunidense": noticias_thenewyorktimes,
#     "The Washington Post - Jornal diário americano publicado em Washington, D.C": noticias_thewashingtonpost,
#     "The Guardian - Jornal diário nacional britânico": noticias_theguardian
# }
todas_noticias = {
    "SCMP": noticias_scmp,
    "RT": noticias_rt,
    "NK News": noticias_nknews,
    "Shine": noticias_shine,
    "Sputnik Global": noticias_sputnik,
    "ICL Notícias": noticias_iclnoticias,
    "Brasil 247": noticias_brasil247,
    "Jornal GGN": noticias_jornalggn,
    "Xinhua": noticias_news_cn,
    "Sputnik Brasil": noticias_noticiabrasil,
    "Opera Mundi": noticias_operamundi,
    "Globo": noticias_globo,
    "CNN Brasil": noticias_cnnbrasil,
    "The New York Times": noticias_thenewyorktimes,
    "The Washington Post": noticias_thewashingtonpost,
    "The Guardian": noticias_theguardian
}

# Enviar o resumo das notícias por e-mail
enviar_email(todas_noticias)
